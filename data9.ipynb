# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
df = pd.read_csv("proteinGroups.csv", low_memory=False)
df.head(10)
# Out:
#   Protein IDs Majority protein IDs Peptide counts (all)  \
# 0  A0A024RBG1           A0A024RBG1                    7
# 1  A0A096LP55               P07919           A0A096LP55
# 2      P0DPI2           A0A0B4J2D5               P0DPI2
# 3      P0DPI3           A0A0U1RR11           A0A0U1RRI6
# 4      A0AV96               Q8TBY0               A0AV96
# 5      A0AVF1               A0AVF1                    5
# 6      A0AVT1               A0AVT1                   35
# 7      A0FGR8               A0FGR8                   24
# 8      A0JLT2               A0JLT2                    3
# 9      A0JNW5               A0JNW5                    3
#
#   Peptide counts (razor+unique) Peptide counts (unique)  \
# 0                             2                       2
# 1                        P07919                       1
# 2                    A0A0B4J2D5                       7
# 3                        P0DPI3              A0A0U1RR11
# 4                            13                       1
# 5                             5                       5
# 6                            35                      35
# 7                            24                      24
# 8                             3                       3
# 9                             3                       3
#
#                                        Protein names Gene names Fasta headers  \
# 0                                                NaN      NUDT4           NaN
# 1                                                  1          1             1
# 2                                                  7          7             7
# 3                                         A0A0U1RRI6          1             1
# 4                                                 13          1            12
# 5                Intraflagellar transport protein 56      TTC26           NaN
# 6        Ubiquitin-like modifier-activating enzyme 6       UBA6           NaN
# 7                           Extended synaptotagmin-2      ESYT2           NaN
# 8  Mediator of RNA polymerase II transcription su...      MED19           NaN
# 9                       UHRF1-binding protein 1-like  UHRF1BP1L           NaN
#
#   Number of proteins                Peptides  ... Unnamed: 1014 Unnamed: 1015  \
# 0                  1                       7  ...           NaN           NaN
# 1                  1                       1  ...           NaN           NaN
# 2                  7                       7  ...           NaN           NaN
# 3                  1                       1  ...           NaN           NaN
# 4                  0  RNA-binding protein 47  ...           NaN           NaN
# 5                  1                       5  ...           NaN           NaN
# 6                  1                      35  ...           NaN           NaN
# 7                  1                      24  ...           NaN           NaN
# 8                  1                       3  ...           NaN           NaN
# 9                  1                       3  ...           NaN           NaN
#
#   Unnamed: 1016 Unnamed: 1017 Unnamed: 1018 Unnamed: 1019 Unnamed: 1020  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
# 5           NaN           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN           NaN
# 7           NaN           NaN           NaN           NaN           NaN
# 8           NaN           NaN           NaN           NaN           NaN
# 9           NaN           NaN           NaN           NaN           NaN
#
#   Unnamed: 1021 Unnamed: 1022 Unnamed: 1023
# 0           NaN           NaN           NaN
# 1           NaN           NaN           NaN
# 2           NaN           NaN           NaN
# 3           NaN           NaN           NaN
# 4           NaN           NaN           NaN
# 5           NaN           NaN           NaN
# 6           NaN           NaN           NaN
# 7           NaN           NaN           NaN
# 8           NaN           NaN           NaN
# 9           NaN           NaN           NaN
#
# [10 rows x 1024 columns]

# %% [markdown]
# # How many proteins were detected in total?

# %%
df['Protein IDs'].nunique()
# Out:
# 7499

# %%
df2 = df[~df['Protein IDs'].str.startswith('CON')]
df3 = df2[~df2['Protein IDs'].str.startswith('REV')]
df3['Protein IDs'].nunique()
# Out:
# 7251

# %%
df3['Protein IDs'].value_counts().sum()
# Out:
# 7251

# %%
df3.shape
# Out:
# (7251, 1024)

# %%
df3.to_csv("my-sample.csv",index_label=False)

# %%
df4 = df3['Protein IDs'].dropna(axis=0)

# %%
df4.shape
# Out:
# (7251,)

# %% [markdown]
# So, total number of unique protein presents are 7251

# %%
df3.head(10)
# Out:
#   Protein IDs Majority protein IDs Peptide counts (all)  \
# 0  A0A024RBG1           A0A024RBG1                    7
# 1  A0A096LP55               P07919           A0A096LP55
# 2      P0DPI2           A0A0B4J2D5               P0DPI2
# 3      P0DPI3           A0A0U1RR11           A0A0U1RRI6
# 4      A0AV96               Q8TBY0               A0AV96
# 5      A0AVF1               A0AVF1                    5
# 6      A0AVT1               A0AVT1                   35
# 7      A0FGR8               A0FGR8                   24
# 8      A0JLT2               A0JLT2                    3
# 9      A0JNW5               A0JNW5                    3
#
#   Peptide counts (razor+unique) Peptide counts (unique)  \
# 0                             2                       2
# 1                        P07919                       1
# 2                    A0A0B4J2D5                       7
# 3                        P0DPI3              A0A0U1RR11
# 4                            13                       1
# 5                             5                       5
# 6                            35                      35
# 7                            24                      24
# 8                             3                       3
# 9                             3                       3
#
#                                        Protein names Gene names Fasta headers  \
# 0                                                NaN      NUDT4           NaN
# 1                                                  1          1             1
# 2                                                  7          7             7
# 3                                         A0A0U1RRI6          1             1
# 4                                                 13          1            12
# 5                Intraflagellar transport protein 56      TTC26           NaN
# 6        Ubiquitin-like modifier-activating enzyme 6       UBA6           NaN
# 7                           Extended synaptotagmin-2      ESYT2           NaN
# 8  Mediator of RNA polymerase II transcription su...      MED19           NaN
# 9                       UHRF1-binding protein 1-like  UHRF1BP1L           NaN
#
#   Number of proteins                Peptides  ... Unnamed: 1014 Unnamed: 1015  \
# 0                  1                       7  ...           NaN           NaN
# 1                  1                       1  ...           NaN           NaN
# 2                  7                       7  ...           NaN           NaN
# 3                  1                       1  ...           NaN           NaN
# 4                  0  RNA-binding protein 47  ...           NaN           NaN
# 5                  1                       5  ...           NaN           NaN
# 6                  1                      35  ...           NaN           NaN
# 7                  1                      24  ...           NaN           NaN
# 8                  1                       3  ...           NaN           NaN
# 9                  1                       3  ...           NaN           NaN
#
#   Unnamed: 1016 Unnamed: 1017 Unnamed: 1018 Unnamed: 1019 Unnamed: 1020  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 4           NaN           NaN           NaN           NaN           NaN
# 5           NaN           NaN           NaN           NaN           NaN
# 6           NaN           NaN           NaN           NaN           NaN
# 7           NaN           NaN           NaN           NaN           NaN
# 8           NaN           NaN           NaN           NaN           NaN
# 9           NaN           NaN           NaN           NaN           NaN
#
#   Unnamed: 1021 Unnamed: 1022 Unnamed: 1023
# 0           NaN           NaN           NaN
# 1           NaN           NaN           NaN
# 2           NaN           NaN           NaN
# 3           NaN           NaN           NaN
# 4           NaN           NaN           NaN
# 5           NaN           NaN           NaN
# 6           NaN           NaN           NaN
# 7           NaN           NaN           NaN
# 8           NaN           NaN           NaN
# 9           NaN           NaN           NaN
#
# [10 rows x 1024 columns]

# %%
df5 = df3.iloc[:,24:30]

# %%
df5
# Out:
#      Unique peptides SW480_1 Unique peptides SW480_2 Unique peptides SW480_3  \
# 0                          2                       2                       2
# 1                          0                       1                       1
# 2                          7                       6                       7
# 3                          1                       1                       1
# 4                          4                      12                      13
# ...                      ...                     ...                     ...
# 7331                       4                       1                       3
# 7332                       5                       5                       5
# 7333                       6                       6                       7
# 7334                       2                       4                       3
# 7335                      17                      22                      21
#
#      Unique peptides SW620_1 Unique peptides SW620_2 Unique peptides Sw620_3
# 0                          2                       2                       2
# 1                          1                       1                       1
# 2                          7                       7                       7
# 3                          1                       1                       1
# 4                         12                       1                       3
# ...                      ...                     ...                     ...
# 7331                       5                       4                       6
# 7332                       1                       2                       2
# 7333                       8                       5                       6
# 7334                       3                       3                       3
# 7335                      21                      21                      23
#
# [7251 rows x 6 columns]

# %%
df6=df5[df5!=0].dropna()
df6.head(20)
# Out:
#    Unique peptides SW480_1 Unique peptides SW480_2 Unique peptides SW480_3  \
# 0                        2                       2                       2
# 1                        0                       1                       1
# 2                        7                       6                       7
# 3                        1                       1                       1
# 4                        4                      12                      13
# 5                        4                       4                       4
# 6                       32                      33                      33
# 7                       24                      23                      24
# 8                        3                       3                       3
# 9                        3                       3                       3
# 10                      16                      20                      19
# 11                       1                       1                       1
# 12                       0                       0                       0
# 13                       9                      11                      11
# 14                       4                       3                       4
# 15                       3                       3                       2
# 16                       1                       1                       1
# 17                       0                       0                       0
# 18                  B4DXR9                  Q03936                  Q96N58
# 19                      24                      25                      25
#
#    Unique peptides SW620_1 Unique peptides SW620_2 Unique peptides Sw620_3
# 0                        2                       2                       2
# 1                        1                       1                       1
# 2                        7                       7                       7
# 3                        1                       1                       1
# 4                       12                       1                       3
# 5                        5                       4                       4
# 6                       33                      32                      33
# 7                       23                      23                      22
# 8                        3                       3                       3
# 9                        2                       3                       2
# 10                      23                      27                      25
# 11                       1                       0                       1
# 12                       0                       1                       0
# 13                      11                      11                      10
# 14                       4                       4                       4
# 15                       3                       4                       4
# 16                       1                       1                       1
# 17                       0                       0                       0
# 18                  Q8N4W9                  Q05481                  A6NN14
# 19                      23                      22                      26

# %%
# Out:
#      Unique peptides SW480_1 Unique peptides SW480_2 Unique peptides SW480_3  \
# 0                          2                       2                       2
# 1                          0                       1                       1
# 2                          7                       6                       7
# 3                          1                       1                       1
# 4                          4                      12                      13
# ...                      ...                     ...                     ...
# 7331                       4                       1                       3
# 7332                       5                       5                       5
# 7333                       6                       6                       7
# 7334                       2                       4                       3
# 7335                      17                      22                      21
#
#      Unique peptides SW620_1 Unique peptides SW620_2 Unique peptides Sw620_3
# 0                          2                       2                       2
# 1                          1                       1                       1
# 2                          7                       7                       7
# 3                          1                       1                       1
# 4                         12                       1                       3
# ...                      ...                     ...                     ...
# 7331                       5                       4                       6
# 7332                       1                       2                       2
# 7333                       8                       5                       6
# 7334                       3                       3                       3
# 7335                      21                      21                      23
#
# [7250 rows x 6 columns]

# %%
df5_new = df5.drop(df5.index[18])

# %%
df5_new.shape
# Out:
# (7250, 6)

# %%
df5_new.head(20)
# Out:
#    Unique peptides SW480_1 Unique peptides SW480_2 Unique peptides SW480_3  \
# 0                        2                       2                       2
# 1                        0                       1                       1
# 2                        7                       6                       7
# 3                        1                       1                       1
# 4                        4                      12                      13
# 5                        4                       4                       4
# 6                       32                      33                      33
# 7                       24                      23                      24
# 8                        3                       3                       3
# 9                        3                       3                       3
# 10                      16                      20                      19
# 11                       1                       1                       1
# 12                       0                       0                       0
# 13                       9                      11                      11
# 14                       4                       3                       4
# 15                       3                       3                       2
# 16                       1                       1                       1
# 17                       0                       0                       0
# 19                      24                      25                      25
# 20                       3                       3                       3
#
#    Unique peptides SW620_1 Unique peptides SW620_2 Unique peptides Sw620_3
# 0                        2                       2                       2
# 1                        1                       1                       1
# 2                        7                       7                       7
# 3                        1                       1                       1
# 4                       12                       1                       3
# 5                        5                       4                       4
# 6                       33                      32                      33
# 7                       23                      23                      22
# 8                        3                       3                       3
# 9                        2                       3                       2
# 10                      23                      27                      25
# 11                       1                       0                       1
# 12                       0                       1                       0
# 13                      11                      11                      10
# 14                       4                       4                       4
# 15                       3                       4                       4
# 16                       1                       1                       1
# 17                       0                       0                       0
# 19                      23                      22                      26
# 20                       3                       2                       3

# %%
df

# %%
df5_new['Unique peptides SW480_1'] = df5_new['Unique peptides SW480_1'].astype('int')
df5_new['Unique peptides SW480_1'].dtype
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-633d339994f1> in <module>
# ----> 1 df5_new['Unique peptides SW480_1'] = df5_new['Unique peptides SW480_1'].astype('int')
#       2 df5_new['Unique peptides SW480_1'].dtype
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5544         else:
#    5545             # else, only a single dtype is given
# -> 5546             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors,)
#    5547             return self._constructor(new_data).__finalize__(self, method="astype")
#    5548
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     593         self, dtype, copy: bool = False, errors: str = "raise"
#     594     ) -> "BlockManager":
# --> 595         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     596
#     597     def convert(
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     404                 applied = b.apply(f, **kwargs)
#     405             else:
# --> 406                 applied = getattr(b, f)(**kwargs)
#     407             result_blocks = _extend_blocks(applied, result_blocks)
#     408
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     593             vals1d = values.ravel()
#     594             try:
# --> 595                 values = astype_nansafe(vals1d, dtype, copy=True)
#     596             except (ValueError, TypeError):
#     597                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/anaconda3/envs/myenv/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     970         # work around NumPy brokenness, #1987
#     971         if np.issubdtype(dtype.type, np.integer):
# --> 972             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     973
#     974         # if we have a datetime/timedelta array of objects
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: 'WASH1'
